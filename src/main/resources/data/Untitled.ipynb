# %%
import pandas as pd

# %%
data = pd.read_csv("./marketplace_data.csv")

# %%
data
# Out:
#            GUN               SKIN     QUALITY                skin_and_name  \
# 0        Tec-9          Flash Out    Mil-Spec            Tec-9 | Flash Out
# 1       MP5-SD              Agent  Restricted               MP5-SD | Agent
# 2       UMP-45          Plastique  Restricted           UMP-45 | Plastique
# 3      SCAR-20            Assault    Mil-Spec            SCAR-20 | Assault
# 4        FAMAS     Decommissioned    Mil-Spec       FAMAS | Decommissioned
# ...        ...                ...         ...                          ...
# 1353       AUG       Bengal Tiger  Classified           AUG | Bengal Tiger
# 1354    XM1014         Red Python    Mil-Spec          XM1014 | Red Python
# 1355     USP-S        Blood Tiger    Mil-Spec          USP-S | Blood Tiger
# 1356     Negev           Bratatat    Mil-Spec             Negev | Bratatat
# 1357  Glock-18   Steel Disruption  Restricted  Glock-18 | Steel Disruption
#
#                           Case
# 0                    CS20 Case
# ...
